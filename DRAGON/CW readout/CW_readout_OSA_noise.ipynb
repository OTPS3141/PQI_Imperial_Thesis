# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as ml

plt.ion()
# %matplotlib widget

# %%
santec_1nm = np.loadtxt(f'Data/OSA noise/WaveData20240802_020.csv', delimiter=',', skiprows=30) # 1nm
santec_50nm = np.loadtxt(f'Data/OSA noise/WaveData20240802_021.csv', delimiter=',', skiprows=30) # 50 nm
EDFA_10nm = np.loadtxt(f'Data/OSA noise/WaveData20240802_022.csv', delimiter=',', skiprows=30) # 10 nm

# %%
index_max_santec_1nm = np.where(santec_1nm[:,1] == np.max(santec_1nm[:,1]))[0][0]
index_max_santec_50nm = np.where(santec_50nm[:,1] == np.max(santec_50nm[:,1]))[0][0]
index_max_EDFA_10nm = np.where(EDFA_10nm[:,1] == np.max(EDFA_10nm[:,1]))[0][0]

# %%
wl_santec_1nm = santec_1nm[index_max_santec_1nm, 0]
wl_santec_50nm = santec_50nm[index_max_santec_50nm, 0]
wl_EDFA_10nm = EDFA_10nm[index_max_EDFA_10nm, 0]

print(f'Maximum power for Santec 1nm: {wl_santec_1nm} nm')
print(f'Maximum power for Santec 50nm: {wl_santec_50nm} nm')
print(f'Maximum power for EDFA 10nm: {wl_EDFA_10nm} nm')
# Out:
# Maximum power for Santec 1nm: 1529.818 nm
# Maximum power for Santec 50nm: 1529.82 nm
# Maximum power for EDFA 10nm: 1529.81 nm

# %%
# Determine a 6GHz window around the peak
f_center = 3e8/(wl_EDFA_10nm*1e-9)

f_lower = f_center - 3e9
f_upper = f_center + 3e9

lambda_lower = 3e8/f_upper
lambda_upper = 3e8/f_lower

print(f'Center frequency: {f_center/1e12} THz')
print(f'Lower frequency: {f_lower/1e12} THz')
print(f'Upper frequency: {f_upper/1e12} THz')
print(f'Lower wavelength: {lambda_lower*1e9} nm')
print(f'Upper wavelength: {lambda_upper*1e9} nm')
print(f'Bandwidth of 6GHz window in nm: {(lambda_upper-lambda_lower)*1e9} nm')
# Out:
# Center frequency: 196.10278400585693 THz
# Lower frequency: 196.09978400585695 THz
# Upper frequency: 196.10578400585695 THz
# Lower wavelength: 1529.7865971716578 nm
# Upper wavelength: 1529.8334035443906 nm
# Bandwidth of 6GHz window in nm: 0.046806372732995156 nm

# %%
# ml.use("pgf")
# ml.rcParams.update({
#     "pgf.texsystem": "pdflatex",
#     'font.family': 'serif',
#     'text.usetex': True,
#     'pgf.rcfonts': False,
#     'font.size': 12,
#     'legend.fontsize': 10,
#     'legend.handlelength': 2
# })

# import pickle
# from matplotlib.collections import LineCollection


# Plot the data with y-axis in log scale
plt.figure()
plt.plot(santec_1nm[:,0], santec_1nm[:,1], label='Santec')
plt.plot(EDFA_10nm[:,0], EDFA_10nm[:,1], label='Santec + EDFA 10 nm')
plt.axvline(lambda_lower*1e9, color='r', linestyle='--', label='6 GHz window')
plt.axvline(lambda_upper*1e9, color='r', linestyle='--')
plt.xlim(wl_EDFA_10nm-0.5, wl_EDFA_10nm+0.5)
plt.xlabel('Wavelength (nm)')
plt.ylabel('Power')
plt.xticks([1529.5, 1529.81, 1530.2, 1530.8])
plt.legend()
plt.title('Semilog plot of OSA noise')
plt.yscale('log')
plt.grid()
plt.show()

ml.pyplot.savefig('OSA_noise.pgf')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/IPython/core/formatters.py:972, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     969     method = get_real_method(obj, self.print_method)
#     971     if method is not None:
# --> 972         return method(include=include, exclude=exclude)
#     973     return None
#     974 else:
#
# File ~/.conda/envs/PQI/lib/python3.11/site-packages/ipympl/backend_nbagg.py:336, in Canvas._repr_mimebundle_(self, **kwargs)
#     333     plaintext = plaintext[:110] + '…'
#     335 buf = io.BytesIO()
# --> 336 self.figure.savefig(buf, format='png', dpi='figure')
#     338 base64_image = b64encode(buf.getvalue()).decode('utf-8')
#     339 self._data_url = f'data:image/png;base64,{base64_image}'
#
# ...

# %%
ml.use("pgf")
ml.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'font.size': 12,
    'legend.fontsize': 10,
    'legend.handlelength': 2
})

import pickle
from matplotlib.collections import LineCollection

plt.figure()
plt.plot(EDFA_10nm[:,0], EDFA_10nm[:,1], label='EDFA 10 nm')
plt.plot(santec_50nm[:,0], santec_50nm[:,1], label='Santec 50 nm')
plt.axvline(lambda_lower*1e9, color='r', linestyle='--', label='6 GHz window')
plt.axvline(lambda_upper*1e9, color='r', linestyle='--')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Power (dBm)')
plt.legend()
plt.yscale('log')
plt.xlim(wl_EDFA_10nm-5, wl_EDFA_10nm+5)
plt.grid()
plt.show()

ml.pyplot.savefig('OSA_noise_50nm.pgf')
# Out:
# /tmp/ipykernel_32306/4057888678.py:26: UserWarning: Matplotlib is currently using pgf, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
# Integrate EDFA from wl_EDFA_10nm-5 to lambda_lower and from lambda_upper to wl_EDFA_10nm+5
index_lower = np.where(EDFA_10nm[:,0] > lambda_lower)[0][0]
index_upper = np.where(EDFA_10nm[:,0] > lambda_upper)[0][0]

power_lower = np.sum(EDFA_10nm[:index_lower, 1])
power_upper = np.sum(EDFA_10nm[index_upper:, 1])

power_in_window = np.sum(EDFA_10nm[index_lower:index_upper, 1])

print(f'Power in 6 GHz window: {power_in_window} dBm')
print(f'Power outside 6 GHz window: {power_lower+power_upper} dBm')

ratio = power_in_window/(power_lower+power_upper)
print(f'Ratio of power in 6 GHz window to power outside 6 GHz window: {ratio}')
# Out:
# Power in 6 GHz window: 0.0 dBm
# Power outside 6 GHz window: 1.39544697 dBm
# Ratio of power in 6 GHz window to power outside 6 GHz window: 0.0

# %%
power_in_window
# Out:
# 0.0
